# %%
import pandas as pd
import numpy as np
data = pd.read_csv("D-DOS-Sentiments.csv")
import requests
from bs4 import BeautifulSoup

# %%
data.head()
# Out:
#                                                 Name    Price  \
# 0  Acer Nitro V AMD Ryzen 5 Hexa Core 7535HS - (1...  ₹56,990
# 1  ASUS TUF Gaming A15 AMD Ryzen 5 Hexa Core 7535...  ₹55,990
# 2  Acer Aspire 7 Intel Core i5 13th Gen 13420H - ...  ₹53,990
# 3  HP Victus Intel Core i5 12th Gen - (16 GB/512 ...  ₹60,990
# 4  HP Victus Intel Core i5 12th Gen 12450H - (8 G...  ₹57,990
#
#                               Features  Ratings
# 0    15.6 Inch, Obsidian Black, 2.1 Kg      4.3
# 1   15.6 Inch, Graphite Black, 2.30 Kg      4.4
# 2            15.6 Inch, Black, 1.99 Kg      4.3
# 3          15.6 inch, Performance Blue      4.4
# 4  15.6 inch, Performance Blue, 2.3 Kg      4.4

# %%
data['Ratings'] = data['Ratings'].astype(float)
data.loc[data['Ratings'] >= 4, 'Sentiments'] = "Positive"
data.loc[data['Ratings'] == 3, 'Sentiments'] = "Neutral"
data.loc[data['Ratings'] < 3, 'Sentiments'] = "Negative"

data
# Out:
#                                                   Name    Price  \
# 0    Acer Nitro V AMD Ryzen 5 Hexa Core 7535HS - (1...  ₹56,990
# 1    ASUS TUF Gaming A15 AMD Ryzen 5 Hexa Core 7535...  ₹55,990
# 2    Acer Aspire 7 Intel Core i5 13th Gen 13420H - ...  ₹53,990
# 3    HP Victus Intel Core i5 12th Gen - (16 GB/512 ...  ₹60,990
# 4    HP Victus Intel Core i5 12th Gen 12450H - (8 G...  ₹57,990
# ..                                                 ...      ...
# 475  Hgworld Wireless Controller Compatible with Pl...   ₹1,264
# 476  AMD Ryzen 5 8500G 3.5 GHz Upto 5 GHz AM5 Socke...  ₹14,759
# 477  AMD Ryzen 5 5600GT 3.6 GHz AM4 Socket 6 Cores ...  ₹12,959
# 478  ZORI Panda Animal Music Headphone Pattern Prin...     ₹151
# 479  AtoZsports SUP VIDEO GAME HAND CONSOLE Handhel...     ₹542
#
#                                               Features  Ratings Sentiments
# 0                    15.6 Inch, Obsidian Black, 2.1 Kg      4.3   Positive
# ...

# %%
data['Sentiments'].fillna("Negative", inplace=True)
data

data.to_csv("updates-d-dos.csv", index=False)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2956\71125545.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Sentiments'].fillna("Negative", inplace=True)

# %%
url = "https://www.flipkart.com/search?q=gaming&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=off&as=off"
headers = {"user-agent" : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36'}

# %%
web = requests.get(url, headers=headers)
soup = BeautifulSoup(web.content, 'html.parser')
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n <head>\n  <link href="https://rukminim2.flixcart.com" rel="preconnect"/>\n  <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/atlas.chunk.8dd48d.css" rel="stylesheet"/>\n  <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.c48a12.css" rel="stylesheet"/>\n  <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.e4e719.css" rel="stylesheet"/>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>\n  <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>\n  <meta content="102988293558" property="fb:page_id"/>\n  <meta content="658873552,624500995,100000233612389" property="fb:admins"/>\n  <link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>\n  <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>\n  <meta content="website" prop
# ...

# %%
container = soup.find('div', attrs={'class' : 'DOjaWF gdgoEp'})
products = container.find_all('div', attrs={'class' : 'slAVV4'})
